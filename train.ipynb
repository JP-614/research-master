# %%
# 1. 필요한 라이브러리들을 모두 import 합니다.
import numpy as np
from stable_baselines3 import DQN
from emg_env_bu import emg_env  # 이전에 만든 강화학습 환경
from cnn_feature_extractor import CNN_feature # 직접 만든 CNN 특징 추출기


print("라이브러리 로딩 완료!")

# 2. 파일 경로 및 주요 변수들을 한 곳에서 관리합니다.
#    경로가 다르다면 이 부분만 수정하면 됩니다.
TRAIN_DATA_DIR = 'リアルタイム_data/train/'
TEST_DATA_DIR = 'リアルタイム_data/test/'
MODEL_SAVE_PATH = "dqn_emg_final_model.zip" # 저장될 모델의 전체 파일 이름

print(f"훈련 데이터 경로: {TRAIN_DATA_DIR}")
print(f"테스트 데이터 경로: {TEST_DATA_DIR}")
print(f"모델 저장 경로: {MODEL_SAVE_PATH}")
# Out:
# 라이브러리 로딩 완료!
# 훈련 데이터 경로: リアルタイム_data/train/
# 테스트 데이터 경로: リアルタイム_data/test/
# 모델 저장 경로: dqn_emg_final_model.zip

# %%
# --- [셀 2: 모델 훈련 및 저장] ---

# 1. 훈련용 환경을 생성합니다. (셀 1에서 정의한 변수 사용)
train_env = emg_env(data_dir=TRAIN_DATA_DIR, train=True)

# 2. 우리가 직접 만든 CNN 특징 추출기를 사용하도록 설정합니다.
policy_kwargs = dict(
    features_extractor_class=CNN_feature,
    features_extractor_kwargs=dict(features_dim=256),  # 최종 특징 벡터의 크기
)

# 3. DQN 모델을 생성합니다.
model = DQN(
    'CnnPolicy',
    train_env,
    policy_kwargs=policy_kwargs,
    buffer_size=50000,       # replay buffer Size
    learning_starts=1000,    # 이 스텝만큼 경험을 쌓은 후 학습 시작
    batch_size=64,           # 한 번에 학습할 데이터의 양
    learning_rate=7e-5,      # 학습률
    gamma=0.99,              # 미래 보상에 대한 할인 계수
    tau=0.0005,                 # 타겟 네트워크 업데이트 강도 (1.0은 하드 업데이트)
    train_freq=4,            # 4 스텝마다 훈련
    gradient_steps=1,        # 각 훈련마다 그래디언트 업데이트 1번 수행
    exploration_fraction=0.1, # 탐험 비율이 0.1이 될 때까지 감소
    exploration_final_eps=0.05, # 최종 탐험 확률
    verbose=1,               # 훈련 과정에 대한 로그 출력
    tensorboard_log="./logs/dqn_emg_custom/" # 텐서보드 로그 저장 경로
)

# 4. 모델 훈련을 시작합니다.
print("===== 모델 훈련 시작 =====")
model.learn(total_timesteps=100000, log_interval=4)
print("===== 모델 훈련 완료 =====")


# 5. 훈련된 모델을 파일로 저장합니다. (셀 1에서 정의한 변수 사용)
model.save(MODEL_SAVE_PATH)
print(f"모델이 '{MODEL_SAVE_PATH}' 경로에 성공적으로 저장되었습니다.")

# 훈련 환경 종료
train_env.close()
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ===== 모델 훈련 시작 =====
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
# Logging to ./logs/dqn_emg_custom/DQN_24
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -79.5    |
# |    exploration_rate | 0.957    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 289      |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 452      |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -81      |
# |    exploration_rate | 0.914    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 213      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 904      |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -80.7    |
# |    exploration_rate | 0.871    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 183      |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 1356     |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.276    |
# |    n_updates        | 88       |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -81.2    |
# |    exploration_rate | 0.828    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 170      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 1808     |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.238    |
# |    n_updates        | 201      |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -81.2    |
# |    exploration_rate | 0.785    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 162      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 2260     |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.304    |
# |    n_updates        | 314      |
# ----------------------------------
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -79.2    |
# |    exploration_rate | 0.742    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 159      |
# |    time_elapsed     | 16       |
# |    total_timesteps  | 2712     |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.311    |
# |    n_updates        | 427      |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -79.6    |
# |    exploration_rate | 0.699    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 156      |
# |    time_elapsed     | 20       |
# |    total_timesteps  | 3164     |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.36     |
# |    n_updates        | 540      |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -77.6    |
# |    exploration_rate | 0.656    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 151      |
# |    time_elapsed     | 23       |
# |    total_timesteps  | 3616     |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.298    |
# |    n_updates        | 653      |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -78      |
# |    exploration_rate | 0.614    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 148      |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 4068     |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.228    |
# |    n_updates        | 766      |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -75.1    |
# |    exploration_rate | 0.571    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 146      |
# |    time_elapsed     | 30       |
# |    total_timesteps  | 4520     |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.213    |
# |    n_updates        | 879      |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -74.1    |
# |    exploration_rate | 0.528    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 144      |
# |    time_elapsed     | 34       |
# |    total_timesteps  | 4972     |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.311    |
# |    n_updates        | 992      |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -71.1    |
# |    exploration_rate | 0.485    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 142      |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 5424     |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.129    |
# |    n_updates        | 1105     |
# ----------------------------------
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -71.7    |
# |    exploration_rate | 0.442    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 141      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 5876     |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.126    |
# |    n_updates        | 1218     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -69.4    |
# |    exploration_rate | 0.399    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 140      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 6328     |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.241    |
# |    n_updates        | 1331     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -67.8    |
# |    exploration_rate | 0.356    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 140      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 6780     |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.169    |
# |    n_updates        | 1444     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -67      |
# |    exploration_rate | 0.313    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 139      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 7232     |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.312    |
# |    n_updates        | 1557     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -63.8    |
# |    exploration_rate | 0.27     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 138      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 7684     |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.272    |
# |    n_updates        | 1670     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -63.8    |
# |    exploration_rate | 0.227    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 138      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 8136     |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.156    |
# |    n_updates        | 1783     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -59.3    |
# |    exploration_rate | 0.184    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 137      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 8588     |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.193    |
# |    n_updates        | 1896     |
# ----------------------------------
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -58.7    |
# |    exploration_rate | 0.141    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 135      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 9040     |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.214    |
# |    n_updates        | 2009     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -55.7    |
# |    exploration_rate | 0.0983   |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 135      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 9492     |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.242    |
# |    n_updates        | 2122     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -52.7    |
# |    exploration_rate | 0.0553   |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 135      |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 9944     |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.201    |
# |    n_updates        | 2235     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -52.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 134      |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 10396    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.24     |
# |    n_updates        | 2348     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -49.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 134      |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 10848    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.164    |
# |    n_updates        | 2461     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -49.1    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 133      |
# |    time_elapsed     | 84       |
# |    total_timesteps  | 11300    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.158    |
# |    n_updates        | 2574     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -43.7    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 133      |
# |    time_elapsed     | 88       |
# |    total_timesteps  | 11752    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.159    |
# |    n_updates        | 2687     |
# ----------------------------------
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -40.9    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 132      |
# |    time_elapsed     | 92       |
# |    total_timesteps  | 12204    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.151    |
# |    n_updates        | 2800     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -36.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 132      |
# |    time_elapsed     | 95       |
# |    total_timesteps  | 12656    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.179    |
# |    n_updates        | 2913     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -31.5    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 131      |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 13108    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.122    |
# |    n_updates        | 3026     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -29.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 131      |
# |    time_elapsed     | 103      |
# |    total_timesteps  | 13560    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.257    |
# |    n_updates        | 3139     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -23.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 131      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 14012    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.171    |
# |    n_updates        | 3252     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -20.3    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 130      |
# |    time_elapsed     | 110      |
# |    total_timesteps  | 14464    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.226    |
# |    n_updates        | 3365     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -15.6    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 129      |
# |    time_elapsed     | 115      |
# |    total_timesteps  | 14916    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.201    |
# |    n_updates        | 3478     |
# ----------------------------------
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -12      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 128      |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 15368    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.179    |
# |    n_updates        | 3591     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -8.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 127      |
# |    time_elapsed     | 124      |
# |    total_timesteps  | 15820    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.177    |
# |    n_updates        | 3704     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -3.98    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 127      |
# |    time_elapsed     | 127      |
# |    total_timesteps  | 16272    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.134    |
# |    n_updates        | 3817     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | -3.36    |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 127      |
# |    time_elapsed     | 131      |
# |    total_timesteps  | 16724    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.186    |
# |    n_updates        | 3930     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 3.26     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 126      |
# |    time_elapsed     | 135      |
# |    total_timesteps  | 17176    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.209    |
# |    n_updates        | 4043     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 5.06     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 126      |
# |    time_elapsed     | 139      |
# |    total_timesteps  | 17628    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.221    |
# |    n_updates        | 4156     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 126      |
# |    time_elapsed     | 143      |
# |    total_timesteps  | 18080    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.258    |
# |    n_updates        | 4269     |
# ----------------------------------
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 13.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 125      |
# |    time_elapsed     | 147      |
# |    total_timesteps  | 18532    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.12     |
# |    n_updates        | 4382     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 16.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 125      |
# |    time_elapsed     | 151      |
# |    total_timesteps  | 18984    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.15     |
# |    n_updates        | 4495     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 21.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 125      |
# |    time_elapsed     | 154      |
# |    total_timesteps  | 19436    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.0863   |
# |    n_updates        | 4608     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 20.6     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 125      |
# |    time_elapsed     | 158      |
# |    total_timesteps  | 19888    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.324    |
# |    n_updates        | 4721     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 26.8     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 124      |
# |    time_elapsed     | 163      |
# |    total_timesteps  | 20340    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.106    |
# |    n_updates        | 4834     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 27.1     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 124      |
# |    time_elapsed     | 167      |
# |    total_timesteps  | 20792    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.194    |
# |    n_updates        | 4947     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 30.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 123      |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 21244    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.355    |
# |    n_updates        | 5060     |
# ----------------------------------
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 33.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 123      |
# |    time_elapsed     | 175      |
# |    total_timesteps  | 21696    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.275    |
# |    n_updates        | 5173     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 35.7     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 122      |
# |    time_elapsed     | 180      |
# |    total_timesteps  | 22148    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.059    |
# |    n_updates        | 5286     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 40.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 122      |
# |    time_elapsed     | 184      |
# |    total_timesteps  | 22600    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.195    |
# |    n_updates        | 5399     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 38.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 122      |
# |    time_elapsed     | 188      |
# |    total_timesteps  | 23052    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.0975   |
# |    n_updates        | 5512     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 43.9     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 121      |
# |    time_elapsed     | 193      |
# |    total_timesteps  | 23504    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.0956   |
# |    n_updates        | 5625     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 43.2     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 120      |
# |    time_elapsed     | 198      |
# |    total_timesteps  | 23956    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.144    |
# |    n_updates        | 5738     |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 46       |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 120      |
# |    time_elapsed     | 202      |
# |    total_timesteps  | 24408    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.124    |
# |    n_updates        | 5851     |
# ----------------------------------
# ...
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 816      |
# |    fps              | 89       |
# |    time_elapsed     | 1030     |
# |    total_timesteps  | 92208    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.0101   |
# |    n_updates        | 22801    |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 820      |
# |    fps              | 89       |
# |    time_elapsed     | 1036     |
# |    total_timesteps  | 92660    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.0127   |
# |    n_updates        | 22914    |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 824      |
# |    fps              | 89       |
# |    time_elapsed     | 1041     |
# |    total_timesteps  | 93112    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.114    |
# |    n_updates        | 23027    |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 828      |
# |    fps              | 89       |
# |    time_elapsed     | 1047     |
# |    total_timesteps  | 93564    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.00711  |
# |    n_updates        | 23140    |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 832      |
# |    fps              | 89       |
# |    time_elapsed     | 1052     |
# |    total_timesteps  | 94016    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.0136   |
# |    n_updates        | 23253    |
# ----------------------------------
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 836      |
# |    fps              | 89       |
# |    time_elapsed     | 1058     |
# |    total_timesteps  | 94468    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.00617  |
# |    n_updates        | 23366    |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 840      |
# |    fps              | 89       |
# |    time_elapsed     | 1063     |
# |    total_timesteps  | 94920    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.204    |
# |    n_updates        | 23479    |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 844      |
# |    fps              | 89       |
# |    time_elapsed     | 1068     |
# |    total_timesteps  | 95372    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.0851   |
# |    n_updates        | 23592    |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 848      |
# |    fps              | 89       |
# |    time_elapsed     | 1074     |
# |    total_timesteps  | 95824    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.00517  |
# |    n_updates        | 23705    |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 852      |
# |    fps              | 89       |
# |    time_elapsed     | 1079     |
# |    total_timesteps  | 96276    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.00692  |
# |    n_updates        | 23818    |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 856      |
# |    fps              | 89       |
# |    time_elapsed     | 1085     |
# |    total_timesteps  | 96728    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.00966  |
# |    n_updates        | 23931    |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 860      |
# |    fps              | 89       |
# |    time_elapsed     | 1090     |
# |    total_timesteps  | 97180    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.00545  |
# |    n_updates        | 24044    |
# ----------------------------------
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 864      |
# |    fps              | 89       |
# |    time_elapsed     | 1096     |
# |    total_timesteps  | 97632    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.00651  |
# |    n_updates        | 24157    |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 868      |
# |    fps              | 88       |
# |    time_elapsed     | 1102     |
# |    total_timesteps  | 98084    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.00365  |
# |    n_updates        | 24270    |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 112      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 872      |
# |    fps              | 88       |
# |    time_elapsed     | 1108     |
# |    total_timesteps  | 98536    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.0133   |
# |    n_updates        | 24383    |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 111      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 876      |
# |    fps              | 88       |
# |    time_elapsed     | 1113     |
# |    total_timesteps  | 98988    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.00411  |
# |    n_updates        | 24496    |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
#
# --- New Episode --- Loading file: ep_20250930_222820_188488_label2.npz, Label: 2 ---
#
# --- New Episode --- Loading file: ep_20250930_222438_678613_label0.npz, Label: 0 ---
#
# --- New Episode --- Loading file: ep_20250930_222932_855019_label3.npz, Label: 3 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 112      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 880      |
# |    fps              | 88       |
# |    time_elapsed     | 1118     |
# |    total_timesteps  | 99440    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.11     |
# |    n_updates        | 24609    |
# ----------------------------------
#
# --- New Episode --- Loading file: ep_20250930_222710_984993_label1.npz, Label: 1 ---
# 모든 데이터를 한 번씩 사용했습니다. 처음부터 다시 시작합니다.
#
# --- New Episode --- Loading file: ep_20250930_223113_190970_label5.npz, Label: 5 ---
#
# --- New Episode --- Loading file: ep_20250930_223029_401040_label4.npz, Label: 4 ---
#
# --- New Episode --- Loading file: ep_20250930_223221_359266_label6.npz, Label: 6 ---
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 113      |
# |    ep_rew_mean      | 112      |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 884      |
# |    fps              | 88       |
# |    time_elapsed     | 1124     |
# |    total_timesteps  | 99892    |
# | train/              |          |
# |    learning_rate    | 7e-05    |
# |    loss             | 0.00958  |
# |    n_updates        | 24722    |
# ----------------------------------
# ===== 모델 훈련 완료 =====
# 모델이 'dqn_emg_final_model.zip' 경로에 성공적으로 저장되었습니다.

# %%
# 1. 파일에 저장된 모델을 불러옵니다. (셀 1에서 정의한 변수 사용)
print(f"'{MODEL_SAVE_PATH}' loading start...")
loaded_model = DQN.load(MODEL_SAVE_PATH)
print("model loading complete!")

# 2. 테스트용 환경을 생성합니다. (셀 1에서 정의한 변수 사용)
test_env = emg_env(data_dir=TEST_DATA_DIR, train=False)

print("\n===== model testing start =====")

#　７つのエピソードを実行
episodes = 7
total_accuracy = 0
#  エージェントが環境で行動するループ
for episode in range(episodes):
    obs, info = test_env.reset()  # 環境をリセットして初期観測を取得
    done = False
    total_reward = 0
    total_action = 0
    total_answer = 0
    # エピソードが終了するまでループ
    while not done:
        action, _  = loaded_model.predict(obs, deterministic=True)  # モデルを使って行動を予測
        obs, reward, terminated, truncated, info = test_env.step(action) # 環境で行動を実行
        done = terminated or truncated
        total_reward += reward  # 報酬を累積
        if action == test_env.episode_label:
            total_action += 1
        total_answer += 1
        accuracy = total_action / total_answer * 100
        print(f"prediction : {action}, answer : {test_env.episode_label}, reward : {reward}")
    print(f"Total Reward : {total_reward}, Accuracy : {accuracy:.1f}%")
    total_accuracy += accuracy    

total_accuracy = total_accuracy / episodes
print(f"overall accuracy : {total_accuracy:.1f}%")

print("===== model teting end =====")
# test環境を閉じる
test_env.close()
# Out:
# 'dqn_emg_final_model.zip' loading start...
# model loading complete!
#
# ===== model testing start =====
#
# --- New Episode --- Loading file: ep_20250930_222618_328456_label0.npz, Label: 0 ---
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 4, answer : 0, reward : -1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 1.0
# prediction : 0, answer : 0, reward : 11.0
# Total Reward : 121.0, Accuracy : 99.1%
#
# --- New Episode --- Loading file: ep_20250930_222800_775700_label1.npz, Label: 1 ---
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 4, answer : 1, reward : -1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 2, answer : 1, reward : -1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 4, answer : 1, reward : -1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 4, answer : 1, reward : -1.0
# prediction : 0, answer : 1, reward : -1.0
# prediction : 2, answer : 1, reward : -1.0
# prediction : 2, answer : 1, reward : -1.0
# prediction : 2, answer : 1, reward : -1.0
# prediction : 2, answer : 1, reward : -1.0
# prediction : 4, answer : 1, reward : -1.0
# prediction : 4, answer : 1, reward : -1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 4, answer : 1, reward : -1.0
# prediction : 4, answer : 1, reward : -1.0
# prediction : 6, answer : 1, reward : -1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 4, answer : 1, reward : -1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 4, answer : 1, reward : -1.0
# prediction : 3, answer : 1, reward : -1.0
# prediction : 4, answer : 1, reward : -1.0
# prediction : 2, answer : 1, reward : -1.0
# prediction : 4, answer : 1, reward : -1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 4, answer : 1, reward : -1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 4, answer : 1, reward : -1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 4, answer : 1, reward : -1.0
# prediction : 4, answer : 1, reward : -1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 4, answer : 1, reward : -1.0
# prediction : 4, answer : 1, reward : -1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 4, answer : 1, reward : -1.0
# prediction : 4, answer : 1, reward : -1.0
# prediction : 4, answer : 1, reward : -1.0
# prediction : 4, answer : 1, reward : -1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 1, answer : 1, reward : 1.0
# prediction : 5, answer : 1, reward : -1.0
# prediction : 1, answer : 1, reward : 1.0
# Total Reward : -13.0, Accuracy : 44.2%
#
# --- New Episode --- Loading file: ep_20250930_222855_526178_label2.npz, Label: 2 ---
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 1, answer : 2, reward : -1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 2, answer : 2, reward : 1.0
# prediction : 5, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# prediction : 6, answer : 2, reward : -1.0
# prediction : 0, answer : 2, reward : -1.0
# Total Reward : -55.0, Accuracy : 25.7%
#
# --- New Episode --- Loading file: ep_20250930_223013_389873_label3.npz, Label: 3 ---
# prediction : 2, answer : 3, reward : -1.0
# prediction : 2, answer : 3, reward : -1.0
# prediction : 5, answer : 3, reward : -1.0
# prediction : 2, answer : 3, reward : -1.0
# prediction : 2, answer : 3, reward : -1.0
# prediction : 2, answer : 3, reward : -1.0
# prediction : 2, answer : 3, reward : -1.0
# prediction : 2, answer : 3, reward : -1.0
# prediction : 2, answer : 3, reward : -1.0
# prediction : 2, answer : 3, reward : -1.0
# prediction : 2, answer : 3, reward : -1.0
# prediction : 2, answer : 3, reward : -1.0
# prediction : 2, answer : 3, reward : -1.0
# prediction : 5, answer : 3, reward : -1.0
# prediction : 2, answer : 3, reward : -1.0
# prediction : 5, answer : 3, reward : -1.0
# prediction : 2, answer : 3, reward : -1.0
# prediction : 2, answer : 3, reward : -1.0
# prediction : 2, answer : 3, reward : -1.0
# prediction : 5, answer : 3, reward : -1.0
# prediction : 2, answer : 3, reward : -1.0
# prediction : 2, answer : 3, reward : -1.0
# prediction : 5, answer : 3, reward : -1.0
# prediction : 2, answer : 3, reward : -1.0
# prediction : 2, answer : 3, reward : -1.0
# prediction : 2, answer : 3, reward : -1.0
# prediction : 2, answer : 3, reward : -1.0
# prediction : 2, answer : 3, reward : -1.0
# prediction : 2, answer : 3, reward : -1.0
# prediction : 5, answer : 3, reward : -1.0
# prediction : 5, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 0, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 0, answer : 3, reward : -1.0
# prediction : 0, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 0, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 0, answer : 3, reward : -1.0
# prediction : 0, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 0, answer : 3, reward : -1.0
# prediction : 0, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 0, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 0, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 5, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 5, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 5, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 5, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# prediction : 6, answer : 3, reward : -1.0
# Total Reward : -113.0, Accuracy : 0.0%
#
# --- New Episode --- Loading file: ep_20250930_223053_373829_label4.npz, Label: 4 ---
# prediction : 2, answer : 4, reward : -1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 6, answer : 4, reward : -1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 1, answer : 4, reward : -1.0
# prediction : 1, answer : 4, reward : -1.0
# prediction : 5, answer : 4, reward : -1.0
# prediction : 1, answer : 4, reward : -1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 2, answer : 4, reward : -1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 1, answer : 4, reward : -1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 1, answer : 4, reward : -1.0
# prediction : 5, answer : 4, reward : -1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 5, answer : 4, reward : -1.0
# prediction : 5, answer : 4, reward : -1.0
# prediction : 1, answer : 4, reward : -1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 5, answer : 4, reward : -1.0
# prediction : 5, answer : 4, reward : -1.0
# prediction : 5, answer : 4, reward : -1.0
# prediction : 5, answer : 4, reward : -1.0
# prediction : 5, answer : 4, reward : -1.0
# prediction : 5, answer : 4, reward : -1.0
# prediction : 5, answer : 4, reward : -1.0
# prediction : 5, answer : 4, reward : -1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 5, answer : 4, reward : -1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 5, answer : 4, reward : -1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 1, answer : 4, reward : -1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 1, answer : 4, reward : -1.0
# prediction : 5, answer : 4, reward : -1.0
# prediction : 5, answer : 4, reward : -1.0
# prediction : 5, answer : 4, reward : -1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 5, answer : 4, reward : -1.0
# prediction : 4, answer : 4, reward : 1.0
# prediction : 5, answer : 4, reward : -1.0
# prediction : 5, answer : 4, reward : -1.0
# prediction : 5, answer : 4, reward : -1.0
# Total Reward : -1.0, Accuracy : 49.6%
#
# --- New Episode --- Loading file: ep_20250930_223148_002978_label5.npz, Label: 5 ---
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 2, answer : 5, reward : -1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 2, answer : 5, reward : -1.0
# prediction : 2, answer : 5, reward : -1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 2, answer : 5, reward : -1.0
# prediction : 2, answer : 5, reward : -1.0
# prediction : 2, answer : 5, reward : -1.0
# prediction : 2, answer : 5, reward : -1.0
# prediction : 2, answer : 5, reward : -1.0
# prediction : 6, answer : 5, reward : -1.0
# prediction : 2, answer : 5, reward : -1.0
# prediction : 6, answer : 5, reward : -1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 6, answer : 5, reward : -1.0
# prediction : 1, answer : 5, reward : -1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 6, answer : 5, reward : -1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 4, answer : 5, reward : -1.0
# prediction : 4, answer : 5, reward : -1.0
# prediction : 4, answer : 5, reward : -1.0
# prediction : 4, answer : 5, reward : -1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 6, answer : 5, reward : -1.0
# prediction : 2, answer : 5, reward : -1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 4, answer : 5, reward : -1.0
# prediction : 2, answer : 5, reward : -1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 2, answer : 5, reward : -1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 2, answer : 5, reward : -1.0
# prediction : 6, answer : 5, reward : -1.0
# prediction : 6, answer : 5, reward : -1.0
# prediction : 6, answer : 5, reward : -1.0
# prediction : 6, answer : 5, reward : -1.0
# prediction : 1, answer : 5, reward : -1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 6, answer : 5, reward : -1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 4, answer : 5, reward : -1.0
# prediction : 1, answer : 5, reward : -1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 1, answer : 5, reward : -1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 1.0
# prediction : 5, answer : 5, reward : 11.0
# Total Reward : 57.0, Accuracy : 70.8%
#
# --- New Episode --- Loading file: ep_20250930_223243_192307_label6.npz, Label: 6 ---
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 5, answer : 6, reward : -1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 5, answer : 6, reward : -1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 1, answer : 6, reward : -1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 0, answer : 6, reward : -1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 0, answer : 6, reward : -1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 1.0
# prediction : 6, answer : 6, reward : 11.0
# Total Reward : 113.0, Accuracy : 95.6%
# overall accuracy : 55.0%
# ===== model teting end =====

# %%
# 1. 파일에 저장된 모델을 불러옵니다. (셀 1에서 정의한 변수 사용)
print(f"'{MODEL_SAVE_PATH}' 경로에서 모델을 불러옵니다...")
loaded_model = DQN.load(MODEL_SAVE_PATH)
print("모델 로딩 완료!")

# 2. 테스트용 환경을 생성합니다. (셀 1에서 정의한 변수 사용)
test_env = emg_env(data_dir=TEST_DATA_DIR, train=False)
obs, info = test_env.reset()
done = False
total_reward = 0

print("\n===== 모델 테스트 시작 =====")
# 에피소드가 끝날 때까지 반복
while not done:
    # 모델을 사용해 현재 관측(obs)에 대한 행동(action)을 예측
    action, _ = loaded_model.predict(obs, deterministic=True)
    
    # 예측한 행동을 환경에 전달하고 다음 상태, 보상 등을 받음
    obs, reward, terminated, truncated, info = test_env.step(action)
    
    # 종료 조건 확인
    done = terminated or truncated
    
    # 총 보상 합산
    total_reward += reward
    
    # 예측 결과와 실제 정답, 보상을 출력
    # action은 numpy 배열이므로 .item()을 사용해 순수한 숫자로 변환
    print(f"예측 행동: {action.item()}, 실제 레이블: {test_env.episode_label}, 이번 스텝 보상: {reward}")

print("===== 모델 테스트 완료 =====")
print(f"에피소드 총 보상: {total_reward}")

# 테스트 환경 종료
test_env.close()
# Out:
# 'dqn_emg_final_model.zip' 경로에서 모델을 불러옵니다...
# 모델 로딩 완료!
#
# --- New Episode --- Loading file: ep_20250930_222618_328456_label0.npz, Label: 0 ---
#
# ===== 모델 테스트 시작 =====
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 4, 실제 레이블: 0, 이번 스텝 보상: -1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 1.0
# 예측 행동: 0, 실제 레이블: 0, 이번 스텝 보상: 11.0
# ===== 모델 테스트 완료 =====
# 에피소드 총 보상: 121.0
